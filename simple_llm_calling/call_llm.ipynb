# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash",
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2
)

response=model.invoke("When is the match of argentina in fifa world cup 2026?")
print(response.text)
# Out:
# The exact match schedule, opponents, and kickoff times for Argentina in the **2026 FIFA World Cup** are **not yet known**.
#
# Here is why and when you can expect this information:
#
# 1. **Qualification is ongoing:** The South American (CONMEBOL) qualifying tournament is still underway and runs through September 2025. While Argentina (the defending champions) is in a strong position to qualify, they must first mathematically secure their spot.
# 2. **The Final Draw:** Once all 48 qualifying teams are decided, FIFA will host the official World Cup Group Stage Draw, which is expected to take place in **late 2025 (likely December)**. This draw will determine which groups the teams are placed in, who they will play, and what days and cities their matches will take place.
#
# ### What we do know about the 2026 World Cup:
# * **Tournament Dates:** The tournament will run from **June 11 to July 19, 2026**.
# ...

# %%
from langchain_groq import ChatGroq

model=ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")
response=model.invoke("When is the match of argentina in fifa world cup 2026?")
print(response.text)
# Out:
# As of now, the exact match schedule for Argentina in the **FIFA World Cup 2026** has not been finalized. Here's what you need to know:
#
# 1. **Group Stage Draw**:
#    The 2026 World Cup group stage will consist of **16 groups of 3 teams** (48 total teams). Argentina must first qualify to confirm their participation. **Qualification for Argentina is ongoing**, with the 2026 South American World Cup qualifiers set to conclude in early 2025. Once qualified, Argentina will be drawn into a group in **late 2024 or early 2025**.
#
# 2. **Group Stage Dates**:
#    The group stage is scheduled for **June 11 – June 26, 2026**. Each team will play three matches (one against each group member) on different dates within this window. The exact dates for Argentina’s matches depend on their group draw and the host cities (United States, Mexico, Canada).
#
# 3. **Knockout Stages**:
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
# ----> 2 import langchain_openai
#
# ModuleNotFoundError: No module named 'langchain_openai'
